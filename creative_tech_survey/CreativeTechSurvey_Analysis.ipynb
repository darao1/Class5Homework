# %%
import csv

# %%
with open('creative_tech_survey.csv', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    for row in csv_reader:
        print(row)
# Out:
# ['Timestamp', 'What is your name? ', 'Would you consider yourself an early bird or a night owl? ', 'What month is your birthday in?', 'What genre of music do you listen to the most?', 'Do you prefer Apple Music or Spotify?', 'What is your favourite thing about yourself?', 'What is your favourite class at the moment?', 'What has been your favourite thing about this apprenticeship so far?']
# ['2022/11/16 1:25:09 PM GMT', 'Rocio', 'Early Bird', 'February', 'Pop and rock', 'Spotify', 'Being multi-faceted', 'Future Machines', 'Learning loads']
# ['2022/11/16 1:26:02 PM GMT', 'Shi Shi', 'Early Bird', 'February', 'Jazz Hiphop', 'Spotify', 'Curiosity', 'All of the above', 'PC Computer!']
# ['2022/11/16 1:48:46 PM GMT', 'Jana', 'Night Owl', 'March', 'Rock', 'Spotify', "I'm a good listener", 'Creative Code', 'The people!']
# ['2022/11/16 2:02:52 PM GMT', 'Tilly', 'It depends', 'June', 'Soul', 'Spotify', 'My grey streak of hair', 'Future Machines', 'How nice everyone is ']
# ...

# %%
with open('creative_tech_survey.csv', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    headers = next(csv_reader)
    for row in csv_reader:
        print(row)
# Out:
# ['2022/11/16 1:25:09 PM GMT', 'Rocio', 'Early Bird', 'February', 'Pop and rock', 'Spotify', 'Being multi-faceted', 'Future Machines', 'Learning loads']
# ['2022/11/16 1:26:02 PM GMT', 'Shi Shi', 'Early Bird', 'February', 'Jazz Hiphop', 'Spotify', 'Curiosity', 'All of the above', 'PC Computer!']
# ['2022/11/16 1:48:46 PM GMT', 'Jana', 'Night Owl', 'March', 'Rock', 'Spotify', "I'm a good listener", 'Creative Code', 'The people!']
# ['2022/11/16 2:02:52 PM GMT', 'Tilly', 'It depends', 'June', 'Soul', 'Spotify', 'My grey streak of hair', 'Future Machines', 'How nice everyone is ']
# ['2022/11/16 2:17:19 PM GMT', 'Jiaze Li', 'Night Owl', 'May', 'HIPHOP', 'Spotify', 'My muscles?', 'Game Engines', 'people']
# ['2022/11/16 2:26:18 PM GMT', 'Jade', 'Night Owl', 'January', 'Electronic', 'Spotify', 'Resilient', 'Creative Code', 'Learning so much!']
# ['2022/11/16 5:41:37 PM GMT', 'Wen', 'Night Owl', 'March', 'Indie', 'Spotify', "I'm empathetic ", 'Game Engines', 'So many work but super fun']
# ...

# %%
headers
# Out:
# ['Timestamp',
#  'What is your name? ',
#  'Would you consider yourself an early bird or a night owl? ',
#  'What month is your birthday in?',
#  'What genre of music do you listen to the most?',
#  'Do you prefer Apple Music or Spotify?',
#  'What is your favourite thing about yourself?',
#  'What is your favourite class at the moment?',
#  'What has been your favourite thing about this apprenticeship so far?']

# %%
row
# Out:
# ['2022/11/18 4:16:37 PM GMT',
#  'Precious',
#  'Night Owl',
#  'November',
#  'Afrobeats and rnb',
#  'Apple Music',
#  'my hair',
#  'Future Machines',
#  'building the raspberry pi']

# %%
with open('creative_tech_survey.csv', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    headers = next(csv_reader)
    data = []
    for row in csv_reader:
        data.append(row)

# %%
data[8]
# Out:
# ['2022/11/17 1:46:00 PM GMT',
#  'jasmine',
#  'Night Owl',
#  'April',
#  'electronic',
#  'Apple Music',
#  'i am kind',
#  'All of the above',
#  'learning new software and getting to know new people with similar interests. good vibes and excited to grow together']

# %%
len(data)
# Out:
# 13

# %%
import pandas as pd

# %%
import matplotlib
# %matplotlib inline

# %%
path = 'creative_tech_survey.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#                    Timestamp What is your name?   \
# 0  2022/11/16 1:25:09 PM GMT               Rocio
# 1  2022/11/16 1:26:02 PM GMT             Shi Shi
# 2  2022/11/16 1:48:46 PM GMT                Jana
# 3  2022/11/16 2:02:52 PM GMT               Tilly
# 4  2022/11/16 2:17:19 PM GMT            Jiaze Li
#
#   Would you consider yourself an early bird or a night owl?   \
# 0                                         Early Bird
# 1                                         Early Bird
# 2                                          Night Owl
# 3                                         It depends
# 4                                          Night Owl
#
#   What month is your birthday in?  \
# 0                        February
# 1                        February
# 2                           March
# 3                            June
# 4                             May
#
#   What genre of music do you listen to the most?  \
# 0                                   Pop and rock
# ...

# %%
data[7:11]
# Out:
#                     Timestamp What is your name?   \
# 7   2022/11/16 8:35:01 PM GMT               Adele
# 8   2022/11/17 1:46:00 PM GMT             jasmine
# 9   2022/11/17 2:00:02 PM GMT                Beth
# 10  2022/11/17 2:07:41 PM GMT                 Kat
#
#    Would you consider yourself an early bird or a night owl?   \
# 7                                          It depends
# 8                                           Night Owl
# 9                                           Night Owl
# 10                                          Night Owl
#
#    What month is your birthday in?  \
# 7                          January
# 8                            April
# 9                         December
# 10                            July
#
#    What genre of music do you listen to the most?  \
# 7                               Afrobeats and r&b
# 8                                      electronic
# 9                                           Metal
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'What is your name? ',
#        'Would you consider yourself an early bird or a night owl? ',
#        'What month is your birthday in?',
#        'What genre of music do you listen to the most?',
#        'Do you prefer Apple Music or Spotify?',
#        'What is your favourite thing about yourself?',
#        'What is your favourite class at the moment?',
#        'What has been your favourite thing about this apprenticeship so far?'],
#       dtype='object')

# %%
display(data)
# Out:
#                     Timestamp What is your name?   \
# 0   2022/11/16 1:25:09 PM GMT               Rocio
# 1   2022/11/16 1:26:02 PM GMT             Shi Shi
# 2   2022/11/16 1:48:46 PM GMT                Jana
# 3   2022/11/16 2:02:52 PM GMT               Tilly
# 4   2022/11/16 2:17:19 PM GMT            Jiaze Li
# 5   2022/11/16 2:26:18 PM GMT                Jade
# 6   2022/11/16 5:41:37 PM GMT                 Wen
# 7   2022/11/16 8:35:01 PM GMT               Adele
# 8   2022/11/17 1:46:00 PM GMT             jasmine
# 9   2022/11/17 2:00:02 PM GMT                Beth
# 10  2022/11/17 2:07:41 PM GMT                 Kat
# 11  2022/11/18 1:13:01 PM GMT          Zishan liu
# 12  2022/11/18 4:16:37 PM GMT            Precious
#
#    Would you consider yourself an early bird or a night owl?   \
# 0                                          Early Bird
# 1                                          Early Bird
# 2                                           Night Owl
# ...

# %%
data['Timestamp']
# Out:
# 0     2022/11/16 1:25:09 PM GMT
# 1     2022/11/16 1:26:02 PM GMT
# 2     2022/11/16 1:48:46 PM GMT
# 3     2022/11/16 2:02:52 PM GMT
# 4     2022/11/16 2:17:19 PM GMT
# 5     2022/11/16 2:26:18 PM GMT
# 6     2022/11/16 5:41:37 PM GMT
# 7     2022/11/16 8:35:01 PM GMT
# 8     2022/11/17 1:46:00 PM GMT
# 9     2022/11/17 2:00:02 PM GMT
# 10    2022/11/17 2:07:41 PM GMT
# 11    2022/11/18 1:13:01 PM GMT
# 12    2022/11/18 4:16:37 PM GMT
# Name: Timestamp, dtype: object

# %%
data.loc[data.Timestamp == '2022/11/16 2:26:18 PM GMT']
# Out:
#                    Timestamp What is your name?   \
# 5  2022/11/16 2:26:18 PM GMT                Jade
#
#   Would you consider yourself an early bird or a night owl?   \
# 5                                          Night Owl
#
#   What month is your birthday in?  \
# 5                         January
#
#   What genre of music do you listen to the most?  \
# 5                                     Electronic
#
#   Do you prefer Apple Music or Spotify?  \
# 5                               Spotify
#
#   What is your favourite thing about yourself?  \
# 5                                    Resilient
#
#   What is your favourite class at the moment?  \
# 5                               Creative Code
#
#   What has been your favourite thing about this apprenticeship so far?
# 5                                  Learning so much!
